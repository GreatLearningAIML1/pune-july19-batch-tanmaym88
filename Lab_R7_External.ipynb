# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
tf.random.set_seed(42)
print(tf.__version__)
# Out:
# 2.1.0-rc1

# %%
import numpy as np
import keras

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test_cat = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Clearing out tensorflow memory
tf.keras.backend.clear_session()

#Initializing Sequential model
model = tf.keras.models.Sequential()

#Reshaping data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

#Normalizing the data
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Adding 1st hidden layer
model.add(tf.keras.layers.Dense(200, activation='relu'))

#Adding 2nd hidden layer
model.add(tf.keras.layers.Dense(100, activation='relu'))

#Adding Dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Adding output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
#Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 200)               157000
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 181,246
# Trainable params: 179,678
# Non-trainable params: 1,568
# _________________________________________________________________

# %%
#Training the network
model.fit(x_train,y_train_cat,          
          validation_data=(x_test,y_test_cat),
          epochs=10,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2985 - accuracy: 0.8891 - val_loss: 0.3392 - val_accuracy: 0.8806
# Epoch 2/10
# 60000/60000 [==============================] - 8s 135us/sample - loss: 0.2847 - accuracy: 0.8931 - val_loss: 0.3500 - val_accuracy: 0.8776
# Epoch 3/10
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.2729 - accuracy: 0.8971 - val_loss: 0.3493 - val_accuracy: 0.8825
# Epoch 4/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2648 - accuracy: 0.9011 - val_loss: 0.3750 - val_accuracy: 0.8829
# Epoch 5/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2493 - accuracy: 0.9049 - val_loss: 0.3584 - val_accuracy: 0.8860
# Epoch 6/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2493 - accuracy: 0.9074 - val_loss: 0.3689 - val_accuracy: 0.8808
# Epoch 7/10
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.2404 - accuracy: 0.9094 - val_loss: 0.3559 - val_accuracy: 0.8878
# Epoch 8/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2320 - accuracy: 0.9118 - val_loss: 0.3854 - val_accuracy: 0.8902
# Epoch 9/10
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2263 - accuracy: 0.9142 - val_loss: 0.3927 - val_accuracy: 0.8866
# Epoch 10/10
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.2194 - accuracy: 0.9168 - val_loss: 0.3519 - val_accuracy: 0.8908

# %%
#Evaluating on test set
model.evaluate(x_test,y_test_cat)
# Out:
# 10000/10000 [==============================] - 1s 95us/sample - loss: 0.3519 - accuracy: 0.8908
# [0.35186991992592814, 0.8908]

# %% [markdown]
# Final Validation accuracy is 89.08%
